# %% [markdown]
# The objective of this project is to create a web scraper which finds jobs related to my query of "junior data (analyst, engineer)" in UK, Danish, or Norwegian locations.

# %%
# Libraries
import csv                        # to export data
from datetime import datetime     # retreive current date
import requests                   # syndicate requests to retreive .html
from bs4 import BeautifulSoup     # parse and extract data from Indeed.com
import pandas as pd

# %% [markdown]
# Indeed URLs look like this:
#
# https://uk.indeed.com/jobs?q=data+engineer&l=United+Kingdom&fromage=7
#
# Where it has "q=" and "l=" I will add into a function so it's easy to search for different queries.

# %%
# Function which creates URL according to our query
def get_url_indeed(position, location):
    # URL template
    template_url = 'https://uk.indeed.com/jobs?q={}&l={}&fromage=3'
    # allow arguments to be inserted into URL
    final_url = template_url.format(position, location).replace(" ", "+")
    return (final_url)

# Demonstration
print('Demonstration URL:\n',
      get_url_indeed(position = 'data analyst',
                     location = 'United Kingdom'))
# Out:
# Demonstration URL:
#  https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3

# %% [markdown]
# Now, to build a demo Web Scaper. For this we need to:
# - Get the **response** for the URL, using the *requests* library.
# - Use the *Beautiful Soup* library to 1) **parse** and then 2) **extract** the data.
#
# We wish to extract information about:
# - Job title.
# - Company.
# - Location.
# - Date of posting.
# - Summary.
# - Salary.
# - Orginal query.
# - URL.

# %%
# Retreiving the response
demo_response = requests.get(get_url_indeed(position = 'accountant',
                                            location = 'united kingdom'))
# Parsing the response
demo_parse = BeautifulSoup(demo_response.text, 'html.parser')
# Get all job cards which appear on a webpage
demo_cards = demo_parse.find_all('div',                    # all 'div' classes
                                 'jobsearch-SerpJobCard')  # part of webpage
print('The number of job cards on each page is',len(demo_cards))
print('\nSelecting the first 5 jobs:\n')
# Extracting information from 1st entry (job card) on the webpage.
for i in range(5):
    demo_title = demo_cards[i].h2.a.get('title')
    print('Job title:', demo_title)
    demo_company = demo_cards[i].find('span', 'company').text.strip()
    print('Company:', demo_company)
    demo_location = demo_cards[i].find('div', 'recJobLoc').get('data-rc-loc')
    print('Location:', demo_location)
    demo_date = demo_cards[i].find('span', 'date date-a11y').text
    print('Date:', demo_date, 'on', datetime.today().strftime('%d-%m-%Y'))
    demo_summary = demo_cards[i].find('div', 'summary').text.strip().replace('\n',' ')
    print('Summary:',demo_summary)
    try:
        demo_salary = demo_cards[i].find('span','salaryText').text.strip()
    except AttributeError:
        demo_salary = 'N/A'
    print('Salary:',demo_salary)
    demo_url = demo_cards[i].h2.a.get('href')
    print('URL:', 'https://www.indeed.com' + demo_url)
    print('')
# Out:
# The number of job cards on each page is 15
#
# Selecting the first 5 jobs:
#
# Job title: Assistant Management Accountant
# Company: Coop
# Location: Manchester
# Date: 3 days ago on 13-06-2021
# Summary: An ACA, CIMA or ACCA part qualified accountant. Up to £30,000 plus benefits (Grade F14). Remote / flexible working, with some weekly travel to Manchester city…
# Salary: £30,000 a year
# URL: https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0Ae8w1yikstuQNQleHQytgaCy3iZ06N5iqAjinK6cLir-wbdh19nDKZIAQTJRkhikUW4NH-V5C2vYe5n8F_7iG9aFUE8Ww3hWhfsbfyhUjyhYxaWcsn2VTcWY0PhiM8jPRFo8KuYqZLNhV9e-as6cOqvtyU3zDTXS_Oc_1YSP2zY6njDN42GqTnD3WPQvb9lLYRlPBRtOBm4CXancrqSdsBVGt09Cd86uAITXIeHEjpbweYqtGAlvfCDlkYjbaIH4hQ0cf2rsAwGTA_Kr5Tau47cRtpdxcTG3UM23_9Gh3ZGbXDdWLVJ6C_yg8rHvZhSYisUjubiosG_74_VLE9inoWfWF7TmryIkdDGjr3u_Cm5XqmGZ-2cw7TrTBRpEZlQQko6ytw6q1SrE--WSmS4D0v5xlEErwJ18zBmLrbzRB_8vzDIa_5KGrK-jFimrE_338=&p=0&fvj=0&vjs=3
#
# Job title: Trainee Accountant
# Company: Ballantyne & Co Chartered Accountants
# Location: Glasgow
# Date: 3 days ago on 13-06-2021
# Summary: We are a long-established chartered accountancy firm with an enviable and varied client base. Enter transactional postings of client financial records and…
# Salary: £16,750 - £17,750 a year
# URL: https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0DtUkx2PUontd6VqZanPdx9yultAyKbocownMgWF-2qqNl5i5A4yqD68ogFqceFP_qhmIYdpXHe5EZKOTklNtkZySMS7BIIRLGtDcjov-cf13drKh10_jv9q9dj7oOc9XmmFInCJU7Xiq2U7u-4JsShQmzHXNcipdo1DREca8Jol5KVibtknUFZhASNRFFsNO--5Roqf5OpRntrQxYD8SbQZmp6-U8bXx5DBXqll_qofWO48Q0MnNO8W0LQ98h3TuUNspIGbqURJBSM-xpVfiXO1BjN5FIM9birnR9apUaXW_RAymPz3kh3YnjqwPpXy7HD-S5jld4MSv-A-sJW5Y-FfH_RmLq2rY81w-58JCwxdMbW8ArCMc7TZ-Do4e5Xqufbsa6LM1FzYDwpl9VRiGkhbQ25a4xe930ea0eO2pP4vYY36t0rz1DKdb591DpYY2WhafTK5jsBiQDL_tVGzNZPhuq0FIDnRKA=&p=1&fvj=1&vjs=3
#
# Job title: Assistant Accountant
# Company: Bespoke Stairlifts
# Location: Huddersfield
# Date: 2 days ago on 13-06-2021
# Summary: In return we will provide a competitive salary, generous holiday allowance, free parking and study support towards achieving ACCA/CIMA.
# Salary: £25,000 a year
# URL: https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0DqfABo6vOpajuzOSYTsA-oZwePq-28tuULHe7oKjSvI4R1r6UlPyQ_aW321dzLa8yvDJ4HUuUr3l00quAM5qCaGfdcNTpln4Zcttz72I7296g3HcV1mtHzSlCQDlK-2DvZsOuDzgo5ldOKHVIPpdgbMWCQQsKkCv4iTq8bVlTZQMbDBzQb99LqJwwhLMXBf5HatuhQXdRbEeRXrPfSFYzmuUyq3HHYwrOxnC-K8ZT4Nzr6H2BzoYj1snIHUUXvzEVI90xmSZAi1TVWL9mu7oCoV__tjftBT1TEdncraXgu5AAOdtssHLAJRzLHAA-C9-4Bh2V8k3Ma7YBdUFBFBSTHNgsMV-KLnV1TJzNWx-POXVGYtyLC2CMvTS-XBaJFBzKJo4fmcB100lNxqwEBEvNzLEGk3bht1wZoUm9uxI1PJaw8jShi13d8xTYJeVnxj-bcmY8pvTDDJcFqhBHoQ5ZhLvzbpovPELA=&p=2&fvj=1&vjs=3
#
# Job title: Trainee Accountant
# Company: Moore Chartered Accountants
# Location: Pickering
# Date: 3 days ago on 13-06-2021
# Summary: Book Keeping on behalf of clients. Preparation of personal and corporate tax returns. Other ad-hoc duties within the firm. Job Types: Full-time, Permanent.
# Salary: N/A
# URL: https://www.indeed.com/pagead/clk?mo=r&ad=-6NYlbfkN0Dxtwr9aeOMQLteRI2JFCNNepHnF3WmFqj964w-RRLpqE_au1TtV3uBUSoBVRnNgQEALY6Npr_iD16g6gBHWALPUIBSplU7kqjy_CMHao-pDwZO4C5vJurKZvqvIjAhG6BTTRaKZ3bgiwu5zQNi2M6hv53wyQA4p108dBifKvZH8Uee4bfX-zqROR-m-N-ENBXlfnYuDl2x0B9GLIv6ntYfNXXFSK2yNVZtxhsuMcxa4gmRAuGTMdp2prvXJWI-xJhtevk1DMhYIJNtCtwcHXTWZn8Tzx1H-PYXsuZEhz4lmUL4Wqvy3bZ51RhWzdnU0LeoDNADhSmW-O4wEx8O3ak-p11VdaAW3OM0BwCxjANhKqtkkTgLQIVh87LI2aRKksSq9fqBUHwDS9L3mkpNu3XRVbT3wTpJgBHFOUbGwW9qWgHc2ZkhjgO8VU6dOAHqf70b--mwXCdkk1eaFYkGeFjDx16GQUCiKl47DvH4aeH7GQ==&p=3&fvj=1&vjs=3
#
# Job title: Management Accountant
# Company: OD Talent Solutions
# Location: Home Based
# Date: 3 days ago on 13-06-2021
# Summary: Line management of part qualified accountants and bookkeepers. You will be expected to develop your own portfolio of Finance Director engagements via new client…
# Salary: £40,000 a year
# URL: https://www.indeed.com/rc/clk?jk=4bb8adb853c6c609&fccid=6b1c82e101354f98&vjs=3

# %% [markdown]
# # Full-code
# Let's now create a function which can be combined with the URL-maker function to simplify things. Aspects which must be improved upon include **1)** Accounting for errors, where no value for field element exists; **2)** Jumping to another page if there is one in the job list.

# %%
def get_job_indeed(job_card):
    job_title = job_card.h2.a.get('title')
    job_company = job_card.find('span', 'company').text.strip()
    job_location = job_card.find('div', 'recJobLoc').get('data-rc-loc')
    job_date = job_card.find('span', 'date date-a11y').text + ' on ' + datetime.today().strftime('%d-%m-%Y')
    job_summary = job_card.find('div', 'summary').text.strip().replace('\n',' ')
    try:
        job_salary = job_card.find('span','salaryText').text.strip()
    except AttributeError:
        job_salary = '-'
    job_url = 'https://uk.indeed.com' + job_card.h2.a.get('href')
    job_extract = (job_title, job_company, job_location, job_date, 
           job_summary, job_salary, job_url)
    return (job_extract)

# %%
def main_function_jobs(position, location):
    job_records = []
    # Part 1: Retreive the appropriate URL using get_url_indeed
    url = get_url_indeed(position, location)
    # Part 2: Parsing and extracting the data
    while True:     # Required to go through multiple pages
        print(url)
        # Retreiving the response
        response = requests.get(url)
        # Parsing the response
        parse = BeautifulSoup(response.text, 'html.parser')
        # Retreiving job cards found on webpage(s)
        cards = parse.find_all('div', 'jobsearch-SerpJobCard')
        
        for i in cards:
            job_record = get_job_indeed(i)
            job_records.append(job_record)
        
        try:
            url = 'https://uk.indeed.com' + parse.find('a', {'aria-label': 'Next'}).get('href')
        except AttributeError:
            break
    return (job_records)

# %%
def webscrape_jobs(level, position, location):
    # Running the webscraper for a given list of positions and locations at various levels
    df = pd.DataFrame()
    for location in location_list:
        for position in position_list:
            for level in level_list:
                df = df.append(main_function_jobs(position = level + position, location = location))
    # N.B. I may wish to filter the data, by title / description, at this stage - TBC
    df.columns = ['job_title','job_company','job_location','job_date','job_summary','job_salary','job_url']
    return (df)

# %%
# Input job titles and locations I am interested in
level_list = ['','junior ','graduate ']
position_list = ['data analyst', 'data engineer', 'machine learning']
location_list = ['United Kingdom']

# Run WebScaper
webscrape_jobs(level = level_list, position = position_list, location = location_list)
# Out:
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=10
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=20
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=30
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=40
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=50
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=60
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=70
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=80
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=90
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=100
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=110
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=120
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=130
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=140
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=150
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=160
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=170
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=180
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=190
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=200
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=210
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=220
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=230
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=240
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=250
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=260
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=270
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=280
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=290
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=300
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=310
# https://uk.indeed.com/jobs?q=data+analyst&l=United+Kingdom&fromage=3&start=320
# https://uk.indeed.com/jobs?q=junior+data+analyst&l=United+Kingdom&fromage=3
# https://uk.indeed.com/jobs?q=junior+data+analyst&l=United+Kingdom&fromage=3&start=10
# https://uk.indeed.com/jobs?q=junior+data+analyst&l=United+Kingdom&fromage=3&start=20
# https://uk.indeed.com/jobs?q=junior+data+analyst&l=United+Kingdom&fromage=3&start=30
# https://uk.indeed.com/jobs?q=junior+data+analyst&l=United+Kingdom&fromage=3&start=40
# https://uk.indeed.com/jobs?q=graduate+data+analyst&l=United+Kingdom&fromage=3
# https://uk.indeed.com/jobs?q=graduate+data+analyst&l=United+Kingdom&fromage=3&start=10
# https://uk.indeed.com/jobs?q=data+engineer&l=United+Kingdom&fromage=3
# https://uk.indeed.com/jobs?q=junior+data+engineer&l=United+Kingdom&fromage=3
# https://uk.indeed.com/jobs?q=junior+data+engineer&l=United+Kingdom&fromage=3&start=10
# https://uk.indeed.com/jobs?q=junior+data+engineer&l=United+Kingdom&fromage=3&start=20
# https://uk.indeed.com/jobs?q=junior+data+engineer&l=United+Kingdom&fromage=3&start=30
# https://uk.indeed.com/jobs?q=junior+data+engineer&l=United+Kingdom&fromage=3&start=40
# https://uk.indeed.com/jobs?q=graduate+data+engineer&l=United+Kingdom&fromage=3
# https://uk.indeed.com/jobs?q=graduate+data+engineer&l=United+Kingdom&fromage=3&start=10
# https://uk.indeed.com/jobs?q=graduate+data+engineer&l=United+Kingdom&fromage=3&start=20
# https://uk.indeed.com/jobs?q=graduate+data+engineer&l=United+Kingdom&fromage=3&start=30
# https://uk.indeed.com/jobs?q=graduate+data+engineer&l=United+Kingdom&fromage=3&start=40
# https://uk.indeed.com/jobs?q=graduate+data+engineer&l=United+Kingdom&fromage=3&start=50
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=10
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=20
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=30
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=40
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=50
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=60
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=70
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=80
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=90
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=100
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=110
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=120
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=130
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=140
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=150
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=160
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=170
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=180
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=190
# https://uk.indeed.com/jobs?q=machine+learning&l=United+Kingdom&fromage=3&start=200
# https://uk.indeed.com/jobs?q=junior+machine+learning&l=United+Kingdom&fromage=3
# https://uk.indeed.com/jobs?q=junior+machine+learning&l=United+Kingdom&fromage=3&start=10
# https://uk.indeed.com/jobs?q=graduate+machine+learning&l=United+Kingdom&fromage=3
#                                             job_title  \
# 0                                Data Quality Analyst
# 1                                        Data Analyst
# 2                                Data Quality Analyst
# 3                            Data Analyst - Telemetry
# 4                  Healthcare Analyst – Data Engineer
# ..                                                ...
# 0            Technology Graduate – 6-Month Internship
# 1   Turing Talent Graduate Program - Women in Tech...
# 2   Turing Talent Internship - Data Science & Mach...
# 3                                 IT Support Engineer
# 4   Turing Talent Graduate Program for PhDs & Mast...
#
#                                           job_company job_location  \
# 0   Wrightington, Wigan and Leigh Teaching Hospita...        Wigan
# 1                                          go-centric      Glasgow
# 2                                                 Sky    Isleworth
# 3                           JPMorgan Chase Bank, N.A.      Glasgow
# 4   NHS Midlands and Lancashire Commissioning Supp...       London
# ..                                                ...          ...
# 0                                     BearingPoint UK       London
# 1                                       Turing Talent       London
# 2                                       Turing Talent       London
# 3                                       Concirrus Ltd       London
# 4                                       Turing Talent       London
#
#                     job_date  \
# 0   3 days ago on 13-06-2021
# 1   2 days ago on 13-06-2021
# 2   3 days ago on 13-06-2021
# 3        Today on 13-06-2021
# 4   2 days ago on 13-06-2021
# ..                       ...
# 0    1 day ago on 13-06-2021
# 1   3 days ago on 13-06-2021
# 2   3 days ago on 13-06-2021
# 3   2 days ago on 13-06-2021
# 4   3 days ago on 13-06-2021
#
#                                           job_summary  \
# 0   You will work very closely with all facets of ...
# 1   An ability to draw conclusions from data. Abil...
# 2   Results-oriented, diligent, champions best pra...
# 3   Strong analytical skills with a concentration ...
# 4   Build and maintain data pipelines used to proc...
# ..                                                ...
# 0   The technology consulting team help clients ga...
# 1   Using deep learning for early diagnosis of dem...
# 2   Using deep learning for early diagnosis of dem...
# 3   Cutting edge risk models driven by the latest ...
# 4   Using deep learning for early diagnosis of dem...
#
#                   job_salary  \
# 0   £24,907 - £30,615 a year
# 1   £23,000 - £25,000 a year
# 2                          -
# 3                          -
# 4   £31,365 - £37,890 a year
# ..                       ...
# 0                          -
# 1   £30,000 - £50,000 a year
# 2             £36,000 a year
# 3                          -
# 4   £25,000 - £50,000 a year
#
#                                               job_url
# 0   https://uk.indeed.com/rc/clk?jk=c15a0fa529f61a...
# 1   https://uk.indeed.com/company/Go--centric/jobs...
# 2   https://uk.indeed.com/rc/clk?jk=483714a287915a...
# 3   https://uk.indeed.com/rc/clk?jk=9a7188e02d214a...
# 4   https://uk.indeed.com/rc/clk?jk=8861d7f92a6f17...
# ..                                                ...
# 0   https://uk.indeed.com/rc/clk?jk=12686108039bda...
# 1   https://uk.indeed.com/company/Turing-Talent/jo...
# 2   https://uk.indeed.com/company/Turing-Talent/jo...
# 3   https://uk.indeed.com/rc/clk?jk=35975c621aebde...
# 4   https://uk.indeed.com/company/Turing-Talent/jo...
#
# [780 rows x 7 columns]

# %% [markdown]
# Excellent. I have a database which contains a list of jobs according to my specification. ✌
#
# The next stage in this project would be to automate running of it, using PyCharm and a postgreSQL database. I could email it to myself...
